# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Администратор\\Downloads\\titanic.csv')

# %%
df
# Out:
#       PassengerID                                           Name PClass  \
# 0               1                   Allen, Miss Elisabeth Walton    1st
# 1               2                    Allison, Miss Helen Loraine    1st
# 2               3            Allison, Mr Hudson Joshua Creighton    1st
# 3               4  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st
# 4               5                  Allison, Master Hudson Trevor    1st
# ...           ...                                            ...    ...
# 1308         1309                             Zakarian, Mr Artun    3rd
# 1309         1310                         Zakarian, Mr Maprieder    3rd
# 1310         1311                               Zenni, Mr Philip    3rd
# 1311         1312                               Lievens, Mr Rene    3rd
# 1312         1313                                 Zimmerman, Leo    3rd
#
#         Age     Sex  Survived  SexCode
# 0     29.00  female         1        1
# ...

# %%
df=df.loc['0','100', ['SexCode']]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df=df.loc['0','100', ['SexCode']]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1333, in _LocIndexer._getitem_tuple(self, tup)
#    1330     return self._getitem_lowerdim(tup)
#    1332 # no multi-index, so validate all of the indexers
# -> 1333 tup = self._validate_tuple_indexer(tup)
#    1335 # ugly hack for GH #836
# ...

# %%
df.plot()
# Out:
# <Axes: >

# %%
new = df.loc['0':'1312', ['Age']]
new.plot()
plt.xlabel('id')
plt.ylabel('Возраст')
plt.title('Зависимость возраста от id пассажира')
# Out:
# Text(0.5, 1.0, 'Зависимость возраста от id пассажира')
